# %%
import pandas as pd

# %%
#Abrir el archivo data/raw/Airbnb_Data.csv
data = pd.read_csv('../data/raw/Airbnb_Data.csv')
data.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  40.696524  -73.991617
# 1  Real Bed              strict          True  ...  40.766115  -73.989040
# 2  Real Bed            moderate          True  ...  40.808110  -73.943756
# 3  Real Bed            flexible          True  ...  37.772004 -122.431619
# 4  Real Bed            moderate          True  ...  38.925627  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#   number_of_reviews review_scores_rating  \
# 0                 2                100.0
# 1                 6                 93.0
# 2                10                 92.0
# 3                 0                  NaN
# 4                 4                 40.0
#
#                                        thumbnail_url  zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201      1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...    10019      3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...    10027      1.0   3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...  94117.0      2.0   2.0
# 4                                                NaN    20009      0.0   1.0
#
# [5 rows x 29 columns]

# %%
print(data.dtypes)
# Out:
# id                          int64
# log_price                 float64
# property_type              object
# room_type                  object
# amenities                  object
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# cancellation_policy        object
# cleaning_fee                 bool
# city                       object
# description                object
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate         object
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# name                       object
# neighbourhood              object
# number_of_reviews           int64
# review_scores_rating      float64
# thumbnail_url              object
# zipcode                    object
# bedrooms                  float64
# beds                      float64
# dtype: object

# %%
#Ver valores nulos de todas las filas
data.isnull().sum()
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   200
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              15864
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# instant_bookable              0
# last_review               15827
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              6872
# number_of_reviews             0
# review_scores_rating      16722
# thumbnail_url              8216
# zipcode                     966
# bedrooms                     91
# beds                        131
# dtype: int64

# %% [markdown]
# Tratamiento de valores nulos

# %%
#Ver valores únicos de cada feature de valores enteros por el nombre de la columna
for column in data.columns:
    if column == 'bathrooms' or column == 'bed_type' or column == 'cancellation_policy' or column == 'cleaning_fee' or column=='host_has_profile_pic' or\
    column == 'host_identity_verified' or column == 'host_response_rate' or column == 'instant_bookable' or column == 'property_type' or column == 'room_type'\
    or column=='bedrooms' or column=='beds' or column=='accommodates' :
        print(column)
        print(data[column].unique())
        print('----------------------------------')
# Out:
# property_type
# ['Apartment' 'House' 'Condominium' 'Loft' 'Townhouse' 'Hostel'
#  'Guest suite' 'Bed & Breakfast' 'Bungalow' 'Guesthouse' 'Dorm' 'Other'
#  'Camper/RV' 'Villa' 'Boutique hotel' 'Timeshare' 'In-law' 'Boat'
#  'Serviced apartment' 'Castle' 'Cabin' 'Treehouse' 'Tipi' 'Vacation home'
#  'Tent' 'Hut' 'Casa particular' 'Chalet' 'Yurt' 'Earth House'
#  'Parking Space' 'Train' 'Cave' 'Lighthouse' 'Island']
# ----------------------------------
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# ----------------------------------
# accommodates
# [ 3  7  5  4  2  6  8  1  9 10 16 11 12 14 13 15]
# ----------------------------------
# bathrooms
# [1.  1.5 2.  nan 2.5 3.  0.5 4.5 5.  0.  4.  3.5 5.5 7.5 6.  8.  7.  6.5]
# ----------------------------------
# bed_type
# ['Real Bed' 'Futon' 'Pull-out Sofa' 'Couch' 'Airbed']
# ----------------------------------
# cancellation_policy
# ['strict' 'moderate' 'flexible' 'super_strict_30' 'super_strict_60']
# ----------------------------------
# cleaning_fee
# [ True False]
# ----------------------------------
# host_has_profile_pic
# ['t' nan 'f']
# ----------------------------------
# host_identity_verified
# ['t' 'f' nan]
# ----------------------------------
# host_response_rate
# [nan '100%' '71%' '68%' '67%' '83%' '50%' '90%' '86%' '92%' '82%' '80%'
#  '89%' '93%' '99%' '0%' '88%' '96%' '70%' '94%' '91%' '25%' '95%' '98%'
#  '62%' '29%' '33%' '81%' '63%' '38%' '60%' '79%' '78%' '75%' '65%' '97%'
#  '87%' '40%' '54%' '53%' '58%' '76%' '30%' '64%' '17%' '20%' '77%' '73%'
#  '41%' '59%' '57%' '85%' '56%' '42%' '44%' '35%' '14%' '74%' '27%' '10%'
#  '84%' '6%' '72%' '36%' '55%' '43%' '13%' '39%' '46%' '26%' '61%' '52%'
#  '23%' '22%' '69%' '66%' '15%' '11%' '31%' '21%' '47%']
# ----------------------------------
# instant_bookable
# ['f' 't']
# ----------------------------------
# bedrooms
# [ 1.  3.  2.  0.  4. nan  5.  6.  7.  8.  9. 10.]
# ----------------------------------
# beds
# [ 1.  3.  2.  7.  4.  6.  5. nan 10.  8. 16.  9. 13. 12. 11. 14. 15.  0.
#  18.]
# ----------------------------------

# %%
#Valores nulos en la columna 'bathrooms'
nulos_bathrooms = data[data['bathrooms'].isnull()]
#Imprimir los valores unicos de cada feature para ver si hay relacion de este valor nulo con otro feature
for col in data.columns:
    print(col)
    if len(nulos_bathrooms[col].unique()) > 5:
        print(nulos_bathrooms[col].unique()[:5], '...')
    else:
        print(nulos_bathrooms[col].unique())
# Out:
# id
# [10994968 12232154 13559613 13068133 13928644] ...
# log_price
# [4.48863637 4.74493213 4.60517019 5.16478597 5.29831737] ...
# property_type
# ['House' 'Apartment' 'Bed & Breakfast' 'Dorm' 'Camper/RV'] ...
# room_type
# ['Private room' 'Entire home/apt' 'Shared room']
# amenities
# ['{Internet,"Wireless Internet",Kitchen,"Pets live on this property",Cat(s),Heating,"Family/kid friendly",Washer,Dryer,Hangers,"Hair dryer","Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'
#  '{Internet,"Wireless Internet",Kitchen,"Pets allowed","Buzzer/wireless intercom",Heating,"Family/kid friendly",Washer}'
#  '{}'
#  '{Internet,"Wireless Internet","Air conditioning",Shampoo,Hangers,"Hair dryer",Iron,"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'
#  '{"Wireless Internet",Kitchen,"Smoking allowed","Pets allowed","Buzzer/wireless intercom",Heating,"Smoke detector","Carbon monoxide detector","Fire extinguisher"}'] ...
# accommodates
# [1 2 4 3 5] ...
# bathrooms
# [nan]
# bed_type
# ['Real Bed' 'Futon' 'Airbed' 'Couch']
# cancellation_policy
# ['moderate' 'strict' 'flexible' 'super_strict_30']
# cleaning_fee
# [ True False]
# city
# ['LA' 'NYC' 'SF' 'Chicago' 'DC'] ...
# description
# ["LOVELY ROOM Cozy, lots of light, twin/single bed (can open into a queen-size), nice closet, WiFi, in a large quaint old 1940's house/duplex in a safe quiet neighborhood. Walking neighborhood with easy access to bus stops.  WHO AM I? Share with me (I'm a comedy director, mid 30's & a really sweet artist in her 20's) I'm super easy going, kind, quiet, respectful, positive, funny, love to meet new people and happy to help you navigate the city. There are two friendly KITTIES! WHO YOU GET TO BE!! I want you to feel at home. You get the run of the house with us, a quaint fully loaded kitchen, living room, wifi, backyard, washer/dryer and easy/free street parking. MOST CENTRAL... ...you can get in Los Angeles! And the neighborhood has everything! WALK TO - Whole Foods, Post Office, Dry Cleaner, etc - LA's best restaurants: The World Famous Improv Comedy Club, The Grove, The Village Idiot, Animal, Urth Cafe, Belmont, Chateau Marmont & The Sunset Strip LONG WALK/SHORT DRIVE -Hollywood Walk of "
#  "Available July 17 to July 30 Minimum 8 nights Short sublet of beautiful East Village apartment --It's close to Union Square, and is the perfect location for your summer vacation to NYC -- Great area for nightlife, restaurants, and close to several subway lines --  Prewar tenement building, 4th floor with view of 13th Street, recently renovated, lots of original details  -- Impeccably clean and attractive bathroom with washing machine -- The kitchen has high-end, green appliances  -- Wireless Internet -- No television but lots of books -- We've listed this for 2, but no problem sleeping more if you're a family traveling with children (we'll provide an air mattress) -- We don't have pets, but you're welcome to bring yours -- We belong to the NYC bike share program, Citibike, and you're welcome to use our keys (free 45 minute rides in Manhattan/Brooklyn--we'll be happy to show you how it works) If it's your first time in New York City, we can assure you that the East Village is one of the"
#  'I am renting my room for 45$ per night. Jan, 4th-12th and Jan 15th - Feb, 8th. Two blocks from the J(Chauncey) and L(Wilson) train. Roomates: Two girls, 26/23 Bed/Internet/Utilities incl. Apartment clean, room with two windows(sunlight), no smoking in the apartment  Cooper at Evergreen '
#  'My sister and I are renting out our extra bedroom. The apartment has a Eat in kitchen and full sized living room. Apartment is in the Back of building so its very quiet. The room has  a comfy single bed. The tenants of the building have all lived here for years and are respectful and quiet. So in turn we return the favor =)  There are many train lines to take you to the best sites. You are walking distance Soho (great shopping), Chinatown (authentic food), LES is walking distances for bars and live music, and in the heart little Italy for coffee and canolli in the morning.  Perks: Bug & Critter free!! Fresh linens and towels provided Dvd Player Non Smoker Clean & tidy The apartment is a 4th floor walk up.  Wireless / cable. *****Room available for monthly sublet Starting April  *** Please inquire.'
#  '1 bedroom apartment. Location is great for tourists- close to Times Square, Broadway, Central Park. Very clean apartment within walking distance to all subway lines. I am going out of town and looking for respectful people who are in search of a reasonably priced place to stay. Apartment has cable and internet, brand new bed, couch and other furniture. Fully stocked kitchen, great for cooking your own meals. **Please do not reserve the apartment without contacting me via email first**'] ...
# first_review
# ['2011-05-20' '2014-01-03' nan '2011-05-30' '2013-05-18'] ...
# host_has_profile_pic
# ['t' 'f' nan]
# host_identity_verified
# ['t' 'f' nan]
# host_response_rate
# ['100%' nan '78%' '96%' '68%'] ...
# host_since
# ['2011-04-01' '2011-01-06' '2012-12-22' '2011-03-22' '2012-12-14'] ...
# instant_bookable
# ['f' 't']
# last_review
# ['2016-11-16' '2015-07-26' nan '2017-09-13' '2016-03-30'] ...
# latitude
# [34.08633778 40.73131103 40.68542293 40.72028817 40.76193736] ...
# longitude
# [-118.36477826  -73.98609197  -73.9073207   -73.99731155  -73.99345563] ...
# name
# ['See Hollywood! The Most Central!' 'Amazing Prewar East Village Apt'
#  'Apt in Bushwick' 'Private Room SOHO' 'Great 1 bedroom- awesome location'] ...
# neighbourhood
# ['West Hollywood' 'East Village' 'Bushwick' 'Little Italy'
#  "Hell's Kitchen"] ...
# number_of_reviews
# [46  2  0 93 33] ...
# review_scores_rating
# [ 99. 100.  nan  96.  92.] ...
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/9790246/e998bd65_original.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/42249609/ac7f3092_original.jpg?aki_policy=small'
#  nan
#  'https://a0.muscache.com/im/pictures/75637053-40e8-491e-b29e-658246b653e1.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/21270396/452bcff0_original.jpg?aki_policy=small'] ...
# zipcode
# ['90046' '10003.0' '11207' '10013' '10036'] ...
# bedrooms
# [ 1. nan  2.  4.  3.]
# beds
# [ 1. nan  2.  3.  4.] ...

# %%
#Ver si 'bathrooms' tiene valores 0, si los tiene cambiarlos por -1 los nulos, caso contrario cambiarlos por 0
num_0_bathrooms = (data['bathrooms'] == 0).sum()
print("Numero de valores 0 en 'bathrooms':", num_0_bathrooms)
if num_0_bathrooms > 0:
    data.fillna({'bathrooms': -1}, inplace=True)
else:
    data.fillna({'bathrooms': 0}, inplace=True)
# Out:
# Numero de valores 0 en 'bathrooms': 198

# %%
#Valores nulos en 'first_review'
nulos_first_review = data[data['first_review'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
for col in nulos_first_review.columns:
    print(col)
    if len(nulos_first_review[col].unique()) > 5:
        print(nulos_first_review[col].unique()[:5], '...')
    else:
        print(nulos_first_review[col].unique())
# Out:
# id
# [13418779 14066228  6226658  2479317  5520582] ...
# log_price
# [6.62007321 4.24849524 4.09434456 6.95654544 3.8286414 ] ...
# property_type
# ['House' 'Apartment' 'Condominium' 'Loft' 'Townhouse'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials}'
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free parking on premises","Pets allowed","Pets live on this property",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector",Essentials,Shampoo,"Lock on bedroom door","24-hour check-in",Hangers}'
#  '{Internet,"Wireless Internet","Air conditioning",Kitchen,"Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,Dryer,Essentials,Hangers,"Laptop friendly workspace"}'
#  '{TV,"Wireless Internet","Air conditioning",Kitchen,Heating,Washer,Dryer,"Smoke detector","Fire extinguisher",Essentials,"Lock on bedroom door","Hair dryer",Iron,"translation missing: en.hosting_amenity_49"}'
#  '{"Wireless Internet","Air conditioning",Kitchen,"Free parking on premises",Gym,"Elevator in building","Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Hangers,Iron,"translation missing: en.hosting_amenity_50"}'] ...
# accommodates
# [4 2 5 1 9] ...
# bathrooms
# [1.  1.5 2.  2.5 3. ] ...
# bed_type
# ['Real Bed' 'Pull-out Sofa' 'Airbed' 'Couch' 'Futon']
# cancellation_policy
# ['flexible' 'moderate' 'strict' 'super_strict_30' 'super_strict_60']
# cleaning_fee
# [ True False]
# city
# ['SF' 'LA' 'Chicago' 'DC' 'NYC'] ...
# description
# ['This light-filled home-away-from-home is super clean and comes with all of the modern amenities travelers could want. Located on a quiet street in the very trendy, super central Lower Haight neighborhood. 15 minutes to Superbowl City! Avail 2/4-2/8. Tucked away on a quaint and quiet one-way street just one block away from the restaurants, shops and bars on Haight Street. There are trains and buses just a block away to get around the city. Super central and trendy!'
#  'Newly furnished room in beach apartment one street up from the water! Relaxing ocean view from the patio in this quaint pet-friendly complex. Right next to the Riviera Village, full of restaurants and shopping! If you would like to rent on days not listed under availability, please message! I may be able to accommodate :)'
#  "Just west of vibrant Wicker Park and Ukranian Village, welcome home to Humboldt Park.  There's a really great urban park just 2 minutes away, where you can get a breath of air and also really great views of the city. This home is shared by 2 working ceramic artists.  Outside of day jobs as freelancers we both keep studio space across town, so the home for us is a clean and comfortable space, with lots of light and creative touches in every corner.  This apartment has the special character of being a duplex with the added bonus of a nice fireplace, which we especially enjoy during the cold Chicago winter!  Currently we are renting one room to a doctor, and I am taking time away from Chicago and offering my room to AirBnb guests. Guests are welcome to be at home in their room, or in either of the common sitting areas.  Kitchen use is permitted, with courtesy of hosts.  Ask for details & kitchen orientation when you check-in. With 2 roommates sharing the duplex on a permanent basis, eithe"
#  'Our place is a modern, spacious apartment on the upper level of a walk-up in the historic Dupont Circle neighborhood. Located on a quiet, but hip street with local bars and restaurants. Exactly 1 mile to the White House! Plus just a few blocks to the Dupont metro station and 14th street/U Street restaurants and bars. Also walking distance to Georgetown, Logan Circle, and Adams Morgan areas. One bedroom, one bathroom. One queen bed in the bedroom, along with a flat screen TV and plenty of space for your luggage.  An additional queen air mattress is available for use in the living room  (Insta-Bed Raised Air Mattress with Never Flat Pump - Queen). We have a memory foam mattress pad, extra sheets, and pillows available for use if this bed is needed. Plenty of room in either the bedroom or living room for the air mattress. I will make my self available to give you a set of keys upon your arrival. You can leave the keys in the apartment when you check out.'
#  'Our place is fully renovated with a nice and clean carpet in the bedroom and living room. You will have your own private bedroom and bathroom. There is one parking spot in the basement. The neighborhood is quiet and nice. Groceries stores, restaurants and The Grove mall nearby. Quite in the middle of LA: - 20 min by car to Santa Monica and Venice beach - 10 min by car to Hollywood boulevard - 20 min by car to Downtown LA Buses and subways stations closed  You will love this place. We will be here to help and guide you.'] ...
# first_review
# [nan]
# host_has_profile_pic
# ['t' nan 'f']
# host_identity_verified
# ['t' 'f' nan]
# host_response_rate
# [nan '100%' '83%' '0%' '50%'] ...
# host_since
# ['2015-04-19' '2016-05-10' '2012-09-10' '2015-05-19' '2017-03-18'] ...
# instant_bookable
# ['f' 't']
# last_review
# [nan '2016-02-01' '2017-04-10' '2017-01-01' '2017-09-13'] ...
# latitude
# [37.77200448 33.81322842 41.90824021 38.91127529 34.06407656] ...
# longitude
# [-122.43161868 -118.38943365  -87.69524167  -77.03727241 -118.34591019] ...
# name
# ['Beautiful Flat in the Heart of SF!' 'Beach Pad 1 min walk to the ocean!'
#  'Sweet Home Chicago' 'Dupont 1 bedroom - 1 mile from the White House!'
#  'Cosy private room/bathroom in Miracle Mile.'] ...
# neighbourhood
# ['Lower Haight' 'Torrance' 'Humboldt Park' 'Dupont Circle' 'Mid-Wilshire'] ...
# number_of_reviews
# [ 0  4 28  1  6] ...
# review_scores_rating
# [nan 20.]
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/72208dad-9c86-41ea-a735-43d933111063.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/be827784-a092-4b3c-8f69-f957414eb48c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/996e04cd-56c5-4705-a420-a2962ac9d85c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/a24c135a-0379-4ed8-a37a-2eadd7acc164.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/14bf8357-c56f-4cb8-8f98-9a76ad040dbb.jpg?aki_policy=small'] ...
# zipcode
# ['94117.0' '90277' '60622' '20009' '90036'] ...
# bedrooms
# [2. 1. 4. 0. 3.] ...
# beds
# [2. 1. 4. 3. 5.] ...

# %%
#Ver el min datetime que acepta un timestamp de pandas
pd.Timestamp.min
# Out:
# Timestamp('1677-09-21 00:12:43.145224193')

# %%
#Cambiar first review a datetime "1677-10-21" en valores nulos
data['first_review'] = data['first_review'].fillna('1677-10-21')
print(data['first_review'].isnull().sum())
#Cambiar el tipo de dato de 'first_review' a datetime
data['first_review'] = pd.to_datetime(data['first_review'])
print(data['first_review'].dtype)
# Out:
# 0
# datetime64[ns]

# %%
#Valores nulos de host_has_profile_pic
nulos_host_has_profile_pic = data[data['host_has_profile_pic'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relación de este valor nulo con otro feature
for col in nulos_host_has_profile_pic.columns:
    print(col)
    if len(nulos_host_has_profile_pic[col].unique()) > 5:
        print(nulos_host_has_profile_pic[col].unique()[:5], '...')
    else:
        print(nulos_host_has_profile_pic[col].unique())
# Out:
# id
# [  262343  4588783 18058045 20973084 15629616] ...
# log_price
# [4.70048037 4.17438727 5.5174529  4.24849524 5.29831737] ...
# property_type
# ['Apartment' 'House' 'Condominium' 'Townhouse' 'Timeshare'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{TV,Kitchen,Heating,"Smoke detector",Essentials,"Lock on bedroom door","Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'
#  '{"Wireless Internet","Air conditioning",Kitchen,Heating,"Smoke detector","Carbon monoxide detector","First aid kit",Essentials,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Bed linens","Extra pillows and blankets","Ethernet connection",Microwave,Refrigerator,"Dishes and silverware",Stove,"Single level home","Luggage dropoff allowed","Long term stays allowed","Wide hallway clearance","Wide doorway","Step-free access","Wide doorway","Wide clearance to bed","Step-free access","Wide doorway","Fixed grab bars for shower & toilet","Wide entryway"}'
#  '{TV,Internet,"Wireless Internet","Air conditioning","Wheelchair accessible",Kitchen,Doorman,Gym,Elevator,"Buzzer/wireless intercom",Heating,"Family/kid friendly","Suitable for events",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,"24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self Check-In",Doorman}'
#  '{"Wireless Internet",Heating,Essentials,Shampoo}'
#  '{TV,"Cable TV",Internet,"Wireless Internet","Air conditioning",Kitchen,"Buzzer/wireless intercom",Heating,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50","Self Check-In","Smart lock",Keypad,Lockbox,Doorman,"Private entrance"}'] ...
# accommodates
# [5 2 6 1 3] ...
# bathrooms
# [ 2.   1.   0.  -1.   1.5] ...
# bed_type
# ['Real Bed' 'Couch' 'Pull-out Sofa' 'Futon']
# cancellation_policy
# ['flexible' 'strict' 'moderate']
# cleaning_fee
# [ True False]
# city
# ['NYC' 'LA' 'DC' 'SF']
# description
# ["Sunny, large, 2 bedroom/2 bath with sleeper couch in quiet clean apartment only 10 min. walk from Prospect Park, Brooklyn Museum and lots of cute places to eat. Only 3 blocks form 3 & 4 Trains, Q & B trains are 10 min away. Private bath, private entrance in front of apartment, Living Rm, Dining Rm and Kitchen. My place is close to Salems Hour, Pels Pie, Prospect Park, Midwood Flats,  and a Lil Mo Wine. My place is good for couples, solo adventurers, business travelers, and groups of 5. Although the apartment is shared I have my own separate suite with its own bathroom and private entrance removed from the common area. It's perfect for a quiet get away or an escape to get some work done. There is a large living/dining space including TV with Chromecast & HiFi speakers and full sized kitchen. The bedrooms are at opposite ends of this very spacious 2.5 bedroom, 2 bath so occupants in each bedroom won't hear each other. The couch in the living room sleeps 1. The front rooms catch morning l"
#  'We are at Brooklyn, to MTA Subway just 10min, to lundry 5min, to chinese style restaurant and chinese style supermarket 5min, new house 1year old, clean and bright room, please contact us for more information, Thank you and have nice trip.'
#  'Modern 2 bedroom apartment, perfect for a family of four/five or couples. King size bed in the master bedroom--guest room has a bunk bed w/ trundle bed. Walking distance to Union square,  Flatiron and Madison Square Park. Safe neighborhood (police precinct nearby) and doorman from 9am to 12am Huge master bedroom w/ King size bed, guest room has a bunk bed and trundle. Flat screen TV in the living room with basic channels, Netfilx, Amazon prime. Entire apt Modern gym in basement I will be available via text/phone. If there are any issues someone can be there to aid. Super lives in the building and doorman from 9a-12am Gramercy is one of the most famous and desirable neighborhoods in NYC. Home to many celebrities, come and see for yourself. Nearby trains--6, N, Q, R  Union Square is also walking distance--4,5,6,L Check in @ 2p and checkout 12pm'
#  "This is a nice space where travelers can come and crash during their stay in the city. It's much cheaper and cozier than a hotel and offers the privacy and comfort that a hostel doesn't have.  Guests will have access to the bedroom, with fresh sheets and towels, as well as the adjacent bathroom. I will provide the wifi code as well.  I will be away, but my roommates will be here during that time. They are very nice and will be happy to help with questions in navigating the city, however, one works from home so it should be relatively quiet during business hours.  The UWS is a great neighborhood. I absolutely love it here. We are surrounded by some of the city's best bars and coffee shops. Just blocks away from Central Park, Riverside Park, and Columbia University's campus.  Yes. We are very close to 3 major subway lines. Very easy to get to midtown (20 minutes on the subway). "
#  'My place is a very stylish apartment located at the best neighborhood of manhattan Lower East Side, a great size for 3 friends or a couple. Everything is walking distance, subway is just one minute away. Downtown Manhattan is 15  mins, Soho 10 mins walk, Lower east side 5 Mins, Chinatown 5 min, Little italy 5 mins walking distance Brooklyn is just one stop with the subway crossing the beautiful Williamsburg Bridge.  Great Cafes, restaurants, nightlife, shops, galleries, you will love it! Welcome to my beautiful, clean and modern apartment. Really comfortable, in a safe neighborhood. Big living room with double sofa bed and double air mattress , and big room with double bed. Really calm during the night, no noise from outside. Cozy for the winter and fresh for the summer with the AC. Gramercy Park is just in front, enjoy the green areas! You can enjoy the whole apartment. Big living room with a single bed sofa, complete kitchen and bathroom. Towels, shampoo, coffee machine and hairdryer'] ...
# first_review
# <DatetimeArray>
# ['1677-10-21 00:00:00', '2017-08-23 00:00:00', '2016-05-09 00:00:00',
#  '2017-06-23 00:00:00', '2015-09-03 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [nan]
# host_identity_verified
# [nan]
# host_response_rate
# [nan]
# host_since
# [nan]
# instant_bookable
# ['t' 'f']
# last_review
# [nan '2017-09-20' '2017-08-11' '2017-09-17' '2017-09-16'] ...
# latitude
# [40.66148884 40.63473727 40.73618434 40.80172651 40.71943093] ...
# longitude
# [-73.95182313 -74.00544769 -73.98451435 -73.96625108 -73.9873361 ] ...
# name
# ['Brooklyn 2 Bdrm Apt. w/ 2 baths' 'Brooklyn travel house #2'
#  'Gramercy 2 bedroom' 'Quiet Room in 4BR UWS Brownstone'
#  'GREAT AND STYLISH APARTMENT! AMAZING LOCATION!'] ...
# neighbourhood
# ['Lefferts Garden' 'Sunset Park' 'Gramercy Park' 'Upper West Side'
#  'Lower East Side'] ...
# number_of_reviews
# [ 0  7  6 39  5] ...
# review_scores_rating
# [nan 94. 93. 91. 98.] ...
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/a1755c3c-c9ec-44a2-ae60-bee9602e6b2b.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/794d2f77-65d6-49f5-b38a-d33cdc00643f.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/e07e70c7-0628-48d7-a6ba-50cebca69110.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/65599996/7dbb5b3c_original.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/3ae5827d-6010-46e5-a719-e005cd60bf1c.jpg?aki_policy=small'] ...
# zipcode
# ['11225' '11219' '10010' '10025' '10002'] ...
# bedrooms
# [2. 1. 3. 0. 5.]
# beds
# [2. 4. 1. 3. 7.] ...

# %%
#Los nulos de host_has_profile_pic tambien tienen nulos en host_identity_verified,host_response_rate y host_since.
# Se cambia los valores t a 1, f a 0 y los nulos a -1. En el caso de host_since como son fechas se cambian a '1677-10-21' los nulos. Únicamente se
# cambian las filas que tienen nulos en host_has_profile_pic, ya que pueden haber otras relaciones extras en los otros campos nulos.
data.loc[data['host_has_profile_pic'].isnull(), 'host_identity_verified'] = data.loc[data['host_has_profile_pic'].isnull(), 'host_identity_verified'].fillna('-1')
data.loc[data['host_has_profile_pic'].isnull(), 'host_response_rate'] = data.loc[data['host_has_profile_pic'].isnull(), 'host_response_rate'].fillna('-1')
data.loc[data['host_has_profile_pic'].isnull(), 'host_since'] = data.loc[data['host_has_profile_pic'].isnull(), 'host_since'].fillna('1677-10-21')
#Se cambio host_has_profile_pic al final ya que es el campo filtro del resto de campos
data.loc[data['host_has_profile_pic'].isnull(), 'host_has_profile_pic'] = data.loc[data['host_has_profile_pic'].isnull(), 'host_has_profile_pic'].fillna('-1')
print(data['host_has_profile_pic'].unique())
print(data['host_identity_verified'].unique())
print(data['host_response_rate'].unique())
print(data['host_since'].unique())

#Mapeo de los otros valores a enteros
data['host_identity_verified'] = data['host_identity_verified'].map({'t': '1', 'f': '0'}).fillna(data['host_identity_verified'])
data['host_has_profile_pic'] = data['host_has_profile_pic'].map({'t': '1', 'f': '0'}).fillna(data['host_has_profile_pic'])
print(data['host_has_profile_pic'].unique())
print(data['host_identity_verified'].unique())
print(data['host_response_rate'].unique())
print(data['host_since'].unique())
#Convertir host_has_profile_pic a entero
data['host_has_profile_pic'] = data['host_has_profile_pic'].astype(int)
#Convertir host_since a datetime
data['host_since'] = pd.to_datetime(data['host_since'])
print(data['host_since'].dtype)
# Out:
# ['t' '-1' 'f']
# ['t' 'f' '-1']
# [nan '100%' '71%' '68%' '67%' '83%' '50%' '90%' '86%' '92%' '82%' '80%'
#  '89%' '-1' '93%' '99%' '0%' '88%' '96%' '70%' '94%' '91%' '25%' '95%'
#  '98%' '62%' '29%' '33%' '81%' '63%' '38%' '60%' '79%' '78%' '75%' '65%'
#  '97%' '87%' '40%' '54%' '53%' '58%' '76%' '30%' '64%' '17%' '20%' '77%'
#  '73%' '41%' '59%' '57%' '85%' '56%' '42%' '44%' '35%' '14%' '74%' '27%'
#  '10%' '84%' '6%' '72%' '36%' '55%' '43%' '13%' '39%' '46%' '26%' '61%'
#  '52%' '23%' '22%' '69%' '66%' '15%' '11%' '31%' '21%' '47%']
# ['2012-03-26' '2017-06-19' '2016-10-25' ... '2008-03-03' '2010-04-30'
#  '2009-08-23']
# ['1' '-1' '0']
# ['1' '0' '-1']
# [nan '100%' '71%' '68%' '67%' '83%' '50%' '90%' '86%' '92%' '82%' '80%'
#  '89%' '-1' '93%' '99%' '0%' '88%' '96%' '70%' '94%' '91%' '25%' '95%'
#  '98%' '62%' '29%' '33%' '81%' '63%' '38%' '60%' '79%' '78%' '75%' '65%'
#  '97%' '87%' '40%' '54%' '53%' '58%' '76%' '30%' '64%' '17%' '20%' '77%'
#  '73%' '41%' '59%' '57%' '85%' '56%' '42%' '44%' '35%' '14%' '74%' '27%'
#  '10%' '84%' '6%' '72%' '36%' '55%' '43%' '13%' '39%' '46%' '26%' '61%'
#  '52%' '23%' '22%' '69%' '66%' '15%' '11%' '31%' '21%' '47%']
# ['2012-03-26' '2017-06-19' '2016-10-25' ... '2008-03-03' '2010-04-30'
#  '2009-08-23']
# datetime64[ns]

# %%
#Valores nulos de host_identity_verified
nulos_host_identity_verified = data[data['host_identity_verified'].isnull()]
if len(nulos_host_identity_verified) > 0:
    #Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
    for col in nulos_host_identity_verified.columns:
        print(col)
        if len(nulos_host_identity_verified[col].unique()) > 5:
            print(nulos_host_identity_verified[col].unique()[:5], '...')
        else:
            print(nulos_host_identity_verified[col].unique())
else:
    print("No hay valores nulos en host_identity_verified")
# Out:
# No hay valores nulos en host_identity_verified

# %%
#Cibiar los valores de host_identity_verified a enteros
data['host_identity_verified'] = data['host_identity_verified'].astype(int)

# %%
#Valores nulos de host_response_rate
nulos_host_response_rate = data[data['host_response_rate'].isnull()]
if len(nulos_host_response_rate) > 0:
    #Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
    for col in nulos_host_response_rate.columns:
        print(col)
        if len(nulos_host_response_rate[col].unique()) > 5:
            print(nulos_host_response_rate[col].unique()[:5], '...')
        else:
            print(nulos_host_response_rate[col].unique())
else:
    print("No hay valores nulos en host_response_rate")
# Out:
# id
# [ 6901257 13418779 14066228  7499179 17615783] ...
# log_price
# [5.01063529 6.62007321 4.24849524 4.31748811 4.00733319] ...
# property_type
# ['Apartment' 'House' 'Loft' 'Condominium' 'Bed & Breakfast'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{"Wireless Internet","Air conditioning",Kitchen,Heating,"Family/kid friendly",Essentials,"Hair dryer",Iron,"translation missing: en.hosting_amenity_50"}'
#  '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials}'
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free parking on premises","Pets allowed","Pets live on this property",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector",Essentials,Shampoo,"Lock on bedroom door","24-hour check-in",Hangers}'
#  '{TV,"Wireless Internet",Kitchen,"Pets allowed",Breakfast,"Pets live on this property",Heating,"Suitable for events",Washer,Dryer,"Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,"Lock on bedroom door",Hangers,"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'
#  '{Internet,"Wireless Internet","Air conditioning",Kitchen,"Free parking on premises","Pets live on this property",Dog(s),Cat(s),Heating,"Family/kid friendly","Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo}'] ...
# accommodates
# [3 4 2 1 6] ...
# bathrooms
# [ 1.  -1.   2.   2.5  1.5] ...
# bed_type
# ['Real Bed' 'Pull-out Sofa' 'Futon' 'Airbed' 'Couch']
# cancellation_policy
# ['strict' 'flexible' 'moderate' 'super_strict_30']
# cleaning_fee
# [ True False]
# city
# ['NYC' 'SF' 'LA' 'Chicago' 'DC'] ...
# description
# ['Beautiful, sunlit brownstone 1-bedroom in the loveliest neighborhood in Brooklyn. Blocks from the promenade and Brooklyn Bridge Park, with their stunning views of Manhattan, and from the great shopping and food.'
#  'This light-filled home-away-from-home is super clean and comes with all of the modern amenities travelers could want. Located on a quiet street in the very trendy, super central Lower Haight neighborhood. 15 minutes to Superbowl City! Avail 2/4-2/8. Tucked away on a quaint and quiet one-way street just one block away from the restaurants, shops and bars on Haight Street. There are trains and buses just a block away to get around the city. Super central and trendy!'
#  'Newly furnished room in beach apartment one street up from the water! Relaxing ocean view from the patio in this quaint pet-friendly complex. Right next to the Riviera Village, full of restaurants and shopping! If you would like to rent on days not listed under availability, please message! I may be able to accommodate :)'
#  "Our place IS Six Corners! Top floor of 4 story building. Close to Big Star, Violet Hour, Bongo Room, Stan's Donuts, Wormhole Coffee, CTA Blue Line, all the bars, all the restaurants, all the shopping! You’ll love our place because of the high ceilings, the views, the location, the people, the ambiance, the rooftop with a Chicago skyline view, the proximity to everything you want to see in the neighborhood and the city. Our place is good for couples, solo adventurers, and furry friends. Wicker Park is noisy on weekends, and your room is on Milwaukee Avenue, so plan for it too be a little louder on Friday and Saturday, and sometimes Sunday as well."
#  'A cozy home on a beautiful tree-lined street centrally located to get anywhere in L.A. in less than 25 minutes...depending on traffic of course. The backyard is a great place to hang or eat at the table under the umbrella... My home is your home :) Private bedroom  Open to someone who is mature and considerate or a couple for short stay.  Double Size Bed/Practically brand new Shared bathroom/But I\'m clean & keep it like you see it in the pics ;) No smoking Great neighborhood Includes wireless internet No cable, sorry :/  But recently got "Apple TV" :) Hardwood floors Ample parking Peaceful backyard with table, chairs and umbrella. Central Air The bus is 1 street light away. (5 min. gets you to Subway which goes from N. Hollywood to downtown) Valley College is 1 mile away. 2 minutes from 101 & 405 freeway 2 minutes from Ventura Blvd. shopping, mall and restaurants 15 minutes to Hollywood 22 minutes to Santa Monica Beach w/out traffic ;) Short term leases are welcome! Please let me know '] ...
# first_review
# <DatetimeArray>
# ['2016-06-18 00:00:00', '1677-10-21 00:00:00', '2016-08-14 00:00:00',
#  '2014-10-20 00:00:00', '2016-07-17 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [1 0]
# host_identity_verified
# [1 0]
# host_response_rate
# [nan]
# host_since
# <DatetimeArray>
# ['2012-03-26 00:00:00', '2015-04-19 00:00:00', '2016-05-10 00:00:00',
#  '2016-07-29 00:00:00', '2012-07-12 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['f' 't']
# last_review
# ['2016-07-18' nan '2016-10-16' '2015-03-14' '2016-07-17'] ...
# latitude
# [40.69652363 37.77200448 33.81322842 41.91030829 34.17536014] ...
# longitude
# [ -73.99161685 -122.43161868 -118.38943365  -87.67526102 -118.43090432] ...
# name
# ['Beautiful brownstone 1-bedroom' 'Beautiful Flat in the Heart of SF!'
#  'Beach Pad 1 min walk to the ocean!'
#  'Private room in Wicker Park loft at Six Corners'
#  'Private Rm. 1Blk. From Sherman Oaks'] ...
# neighbourhood
# ['Brooklyn Heights' 'Lower Haight' 'Torrance' 'Wicker Park' 'Valley Glen'] ...
# number_of_reviews
# [ 2  0 15  1  4] ...
# review_scores_rating
# [100.  nan  91.  95.  97.] ...
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/6d7cbbf7-c034-459c-bc82-6522c957627c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/72208dad-9c86-41ea-a735-43d933111063.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/be827784-a092-4b3c-8f69-f957414eb48c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/f382cb5a-1ea7-4b80-8a1f-1ce5190fa38e.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/14384442/48d23f7d_original.jpg?aki_policy=small'] ...
# zipcode
# ['11201' '94117.0' '90277' '60622' '91401'] ...
# bedrooms
# [1. 2. 3. 0. 4.] ...
# beds
# [1. 2. 3. 4. 5.] ...

# %%
#Llenar los nulos con -1 en host_response_rate
data['host_response_rate'] = data['host_response_rate'].fillna('-1')
#SI se tiene el simbolo % se quita y se convierte a entero
data['host_response_rate'] = data['host_response_rate'].str.replace('%', '').astype(int)

# %%
#Valores nulos de host_since
nulos_host_since = data[data['host_since'].isnull()]
if len(nulos_host_since) > 0:
    #Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
    for col in nulos_host_since.columns:
        print(col)
        if len(nulos_host_since[col].unique()) > 5:
            print(nulos_host_since[col].unique()[:5], '...')
        else:
            print(nulos_host_since[col].unique())
else:
    print("No hay valores nulos en host_since")
# Out:
# No hay valores nulos en host_since

# %%
#Valores nulos en 'last_review'}
nulos_last_review = data[data['last_review'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
for col in nulos_last_review.columns:
    print(col)
    if len(nulos_last_review[col].unique()) > 5:
        print(nulos_last_review[col].unique()[:5], '...')
    else:
        print(nulos_last_review[col].unique())
# Out:
# id
# [13418779 14066228  6226658  2479317  5520582] ...
# log_price
# [6.62007321 4.24849524 4.09434456 6.95654544 3.8286414 ] ...
# property_type
# ['House' 'Apartment' 'Condominium' 'Loft' 'Townhouse'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials}'
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free parking on premises","Pets allowed","Pets live on this property",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector",Essentials,Shampoo,"Lock on bedroom door","24-hour check-in",Hangers}'
#  '{Internet,"Wireless Internet","Air conditioning",Kitchen,"Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,Dryer,Essentials,Hangers,"Laptop friendly workspace"}'
#  '{TV,"Wireless Internet","Air conditioning",Kitchen,Heating,Washer,Dryer,"Smoke detector","Fire extinguisher",Essentials,"Lock on bedroom door","Hair dryer",Iron,"translation missing: en.hosting_amenity_49"}'
#  '{"Wireless Internet","Air conditioning",Kitchen,"Free parking on premises",Gym,"Elevator in building","Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Hangers,Iron,"translation missing: en.hosting_amenity_50"}'] ...
# accommodates
# [4 2 5 1 9] ...
# bathrooms
# [1.  1.5 2.  2.5 3. ] ...
# bed_type
# ['Real Bed' 'Pull-out Sofa' 'Airbed' 'Couch' 'Futon']
# cancellation_policy
# ['flexible' 'moderate' 'strict' 'super_strict_30' 'super_strict_60']
# cleaning_fee
# [ True False]
# city
# ['SF' 'LA' 'Chicago' 'DC' 'NYC'] ...
# description
# ['This light-filled home-away-from-home is super clean and comes with all of the modern amenities travelers could want. Located on a quiet street in the very trendy, super central Lower Haight neighborhood. 15 minutes to Superbowl City! Avail 2/4-2/8. Tucked away on a quaint and quiet one-way street just one block away from the restaurants, shops and bars on Haight Street. There are trains and buses just a block away to get around the city. Super central and trendy!'
#  'Newly furnished room in beach apartment one street up from the water! Relaxing ocean view from the patio in this quaint pet-friendly complex. Right next to the Riviera Village, full of restaurants and shopping! If you would like to rent on days not listed under availability, please message! I may be able to accommodate :)'
#  "Just west of vibrant Wicker Park and Ukranian Village, welcome home to Humboldt Park.  There's a really great urban park just 2 minutes away, where you can get a breath of air and also really great views of the city. This home is shared by 2 working ceramic artists.  Outside of day jobs as freelancers we both keep studio space across town, so the home for us is a clean and comfortable space, with lots of light and creative touches in every corner.  This apartment has the special character of being a duplex with the added bonus of a nice fireplace, which we especially enjoy during the cold Chicago winter!  Currently we are renting one room to a doctor, and I am taking time away from Chicago and offering my room to AirBnb guests. Guests are welcome to be at home in their room, or in either of the common sitting areas.  Kitchen use is permitted, with courtesy of hosts.  Ask for details & kitchen orientation when you check-in. With 2 roommates sharing the duplex on a permanent basis, eithe"
#  'Our place is a modern, spacious apartment on the upper level of a walk-up in the historic Dupont Circle neighborhood. Located on a quiet, but hip street with local bars and restaurants. Exactly 1 mile to the White House! Plus just a few blocks to the Dupont metro station and 14th street/U Street restaurants and bars. Also walking distance to Georgetown, Logan Circle, and Adams Morgan areas. One bedroom, one bathroom. One queen bed in the bedroom, along with a flat screen TV and plenty of space for your luggage.  An additional queen air mattress is available for use in the living room  (Insta-Bed Raised Air Mattress with Never Flat Pump - Queen). We have a memory foam mattress pad, extra sheets, and pillows available for use if this bed is needed. Plenty of room in either the bedroom or living room for the air mattress. I will make my self available to give you a set of keys upon your arrival. You can leave the keys in the apartment when you check out.'
#  'Our place is fully renovated with a nice and clean carpet in the bedroom and living room. You will have your own private bedroom and bathroom. There is one parking spot in the basement. The neighborhood is quiet and nice. Groceries stores, restaurants and The Grove mall nearby. Quite in the middle of LA: - 20 min by car to Santa Monica and Venice beach - 10 min by car to Hollywood boulevard - 20 min by car to Downtown LA Buses and subways stations closed  You will love this place. We will be here to help and guide you.'] ...
# first_review
# <DatetimeArray>
# ['1677-10-21 00:00:00']
# Length: 1, dtype: datetime64[ns]
# host_has_profile_pic
# [ 1 -1  0]
# host_identity_verified
# [ 1  0 -1]
# host_response_rate
# [ -1 100  83   0  50] ...
# host_since
# <DatetimeArray>
# ['2015-04-19 00:00:00', '2016-05-10 00:00:00', '2012-09-10 00:00:00',
#  '2015-05-19 00:00:00', '2017-03-18 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['f' 't']
# last_review
# [nan]
# latitude
# [37.77200448 33.81322842 41.90824021 38.91127529 34.06407656] ...
# longitude
# [-122.43161868 -118.38943365  -87.69524167  -77.03727241 -118.34591019] ...
# name
# ['Beautiful Flat in the Heart of SF!' 'Beach Pad 1 min walk to the ocean!'
#  'Sweet Home Chicago' 'Dupont 1 bedroom - 1 mile from the White House!'
#  'Cosy private room/bathroom in Miracle Mile.'] ...
# neighbourhood
# ['Lower Haight' 'Torrance' 'Humboldt Park' 'Dupont Circle' 'Mid-Wilshire'] ...
# number_of_reviews
# [0 1 2 5]
# review_scores_rating
# [nan 20.]
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/72208dad-9c86-41ea-a735-43d933111063.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/be827784-a092-4b3c-8f69-f957414eb48c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/996e04cd-56c5-4705-a420-a2962ac9d85c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/a24c135a-0379-4ed8-a37a-2eadd7acc164.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/14bf8357-c56f-4cb8-8f98-9a76ad040dbb.jpg?aki_policy=small'] ...
# zipcode
# ['94117.0' '90277' '60622' '20009' '90036'] ...
# bedrooms
# [2. 1. 4. 0. 3.] ...
# beds
# [2. 1. 4. 3. 5.] ...

# %%
#Cambiar last review a datetime "1677-10-21" en valores nulos
data['last_review'] = data['last_review'].fillna('1677-10-21')
print(data['last_review'].isnull().sum())
#Cambiar el tipo de dato de 'last_review' a datetime
data['last_review'] = pd.to_datetime(data['last_review'])
print(data['last_review'].dtype)
# Out:
# 0
# datetime64[ns]

# %%
#Valores nulos en 'neighbourhood'
nulos_neighbourhood = data[data['neighbourhood'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
if len(nulos_neighbourhood) > 0:
    for col in nulos_neighbourhood.columns:
        print(col)
        if len(nulos_neighbourhood[col].unique()) > 5:
            print(nulos_neighbourhood[col].unique()[:5], '...')
        else:
            print(nulos_neighbourhood[col].unique())
else:
    print("No hay valores nulos en neighbourhood")
# Out:
# id
# [11825529  5385260   583490 19407360   851978] ...
# log_price
# [4.41884061 3.58351894 4.95582706 4.55387689 5.19295685] ...
# property_type
# ['Apartment' 'House' 'Condominium' 'Townhouse' 'Other'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{TV,Internet,"Wireless Internet","Air conditioning",Pool,Kitchen,"Free parking on premises",Gym,"Elevator in building","Hot tub",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Hair dryer","Laptop friendly workspace"}'
#  '{"Wireless Internet","Air conditioning",Kitchen,"Free parking on premises",Heating,"Family/kid friendly",Washer,Essentials,Shampoo,Hangers,"Hair dryer","Laptop friendly workspace","translation missing: en.hosting_amenity_50"}'
#  '{Kitchen,Heating,"Smoke detector","Carbon monoxide detector",Essentials,"Hair dryer","translation missing: en.hosting_amenity_50"}'
#  '{TV,"Wireless Internet",Pool,Kitchen,"Elevator in building","Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,"Lock on bedroom door","Laptop friendly workspace","translation missing: en.hosting_amenity_50"}'
#  '{TV,Internet,"Wireless Internet","Air conditioning",Pool,Kitchen,"Free parking on premises","Smoking allowed","Pets allowed",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector",Shampoo}'] ...
# accommodates
# [3 2 4 6 1] ...
# bathrooms
# [1.  0.5 1.5 2.5 5. ] ...
# bed_type
# ['Real Bed' 'Pull-out Sofa' 'Futon' 'Airbed' 'Couch']
# cancellation_policy
# ['moderate' 'strict' 'flexible' 'super_strict_60' 'super_strict_30']
# cleaning_fee
# [ True False]
# city
# ['LA' 'DC' 'Chicago' 'SF' 'NYC']
# description
# ['Warm and cozy studio with full kitchen and bathroom. Big balcony. Parking included. Walk to the beach, rent a bike, eat at variety of restaurants, see boats at Marina harbor! Great location! Friendly neighborhood! Meet locals at "Cow\'s End" famous coffee and wrap cafe.  Great experience all around. This is a non smoking apartment. Warm and cozy studio with full kitchen and bathroom. Big balcony. Parking included. Walk to the beach, rent a bike, eat at variety of restaurants, see boats at Marina harbor! Great location! Friendly neighborhood! Meet locals at "Cow\'s End" famous coffee and wrap cafe.  Great experience all around. Close to the beach, lots of entertainment, balcony,  full kitchen. Gated parking, swimming pool, beach activities, Venice Beach, Marina Harbor At the check in, to deliver the keys. Quite peaceful place, friendly locals, fresh ocean breeze, Venice canals, marina harbor. Yes, the is Bus and uber Gated parking, swimming pool, beach activities, Venice Beach, Marina Har'
#  "Quiet community. Close to supermarkets,restaurants,60 freeway.Looking forward to provide you with high quality service  安全宁静的街区, 近华人及韩国超市,餐厅,近60号高速。欢迎旅行商住 宽敞、明亮、干净、整洁、出入方便 Available kitchen,laundry,living room 可使用厨房洗衣间及客厅 Anytime contact with message or email.phone call available 9am to 7pm. 任何时间的信息和邮箱都可以。电话请在太平洋时间早上9点至晚上7点之间 房客须知:  1、房客之间不允许私下擅自更换房间,必须经由管理员,以及双方房客许可,由管理员监督更换房间。  1, between the tenants are not allowed to privately change the room, must be by the administrator, and the two sides permit tenants, supervise the replacement of the room by the administrator. 2、请认准自己预定房间的号码拿取钥匙,不得进入非预定房间。 2, please look for their own room number to pick up the key, not to enter the not you booking room. 3、预定房间请看准描述选定房间,如描述不清请向管理员咨询,预定后既视为认可不给予任何更换。 3, booking room, please see the description of the selected room, such as the description is unclear, please ask to the administrator, when confired booked room,we don't given any replacement. 4、请自行确认是否预定想要的房源,如不清楚请及时询问管理员,如确认预定,管理员既视为满意本房源,不再对预定进行"
#  'This apartment is charming and wonderful. Beautiful plaster walls 9 foot ceilings hardwood floors throughout. ..LOOKING FOR "SOLID GUEST" , for a "SOLID Amt OF DAYS inMAY"......Kitchen floors & counter are imperfect thru age.The living room window is two French doors that opens out onto palm fronds right before you. Think of the Eagles song hotel California and imagine an apartment for that song this is it.. 9 foot curved living room and bedroom ceiling. Hardwood floors hand trowel plaster walls and ceiling .. vintage and historical Long Beach is super close to all parts of LA look at a map and see. There are many restaurants and shops with in the Long Beach area to have good food for a reasonable price. I am very happy to share local information tailored to your interest and curiosity\'s (READ MY 22 PREVIOUS REVIEWS) ...This listing is  when you have the entire Home to yourself. I might at your arrival to pass the key/ welcome you upon arrival…Otherwise I\'m available for questions and '
#  'Retro, Melrose Place-esque studio apartment steps away from Sunset Blvd + close to all the action in West Hollywood and Hollywood.  2-minute walk to 8000 Sunset Plaza (Starbucks, Crunch Gym, Trader Joes, restaurants, smoothies..).  Building is secure with amazing neighbors, vibe, and energy. Mediterranean-style building with extremely well taken care of pool. Super comfortable, large studio apartment. Bedroom, stocked bathroom, refrigerator, coffee maker, WiFi, office area, Apple TV .'
#  "This home is filled with love & laughter! Modern, Clean French doors, double door bedroom, flat screen, ps4, movies, Netflix and A/C! Pool/Parking! Fully furnished right in the center of hollywood! 5 minutes walking to Chinese theatre and near most exciting spots all the tourists go! Parking included! You'llBeLivingALosAngelesLifeTheRightWay! :)"] ...
# first_review
# <DatetimeArray>
# ['2017-03-10 00:00:00', '2017-04-03 00:00:00', '2017-03-25 00:00:00',
#  '2016-07-17 00:00:00', '2015-12-30 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [ 1  0 -1]
# host_identity_verified
# [ 0  1 -1]
# host_response_rate
# [100  -1  50  94  67] ...
# host_since
# <DatetimeArray>
# ['2017-03-03 00:00:00', '2017-03-12 00:00:00', '2012-11-20 00:00:00',
#  '2013-06-20 00:00:00', '2015-09-26 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['t' 'f']
# last_review
# <DatetimeArray>
# ['2017-04-21 00:00:00', '2017-04-16 00:00:00', '2017-04-06 00:00:00',
#  '2016-07-17 00:00:00', '2016-08-03 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# latitude
# [33.9804544  33.99256298 33.77852647 34.10068649 34.05158405] ...
# longitude
# [-118.46282074 -117.89599661 -118.14592576 -118.36420358 -118.24292309] ...
# name
# ['Beach Town Studio and Parking!!!11h' 'No.7 Queen Size Cozy Room 舒适大床房'
#  'VINTAGE 1930s Mediteranian Apt. (NOT a party SPOT)'
#  'Retro West Hollywood Studio + Pool!' 'Sweet Hollywood Home / 1bd1bth'] ...
# neighbourhood
# [nan]
# number_of_reviews
# [15  2  1  4  0] ...
# review_scores_rating
# [ 97.  90. 100.  95.  nan] ...
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/4c920c60-43dc-4169-a0da-ccf37f1d7a94.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/8d2f08ce-bf65-4018-a7b0-18823a7882a7.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/9ebde7af-0dda-4048-843d-011501b34575.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/c67ecdec-acdd-49d6-80e5-bed6fcc70805.jpg?aki_policy=small'
#  nan] ...
# zipcode
# ['90292' '91748' '90804' nan '90028'] ...
# bedrooms
# [1. 2. 3. 0. 4.] ...
# beds
# [1. 2. 3. 4. 5.] ...

# %%
#Como no hay relaciones se cambian los valores nulos a 'Unknown Neighbourhood'
data['neighbourhood'] = data['neighbourhood'].fillna('Unknown Neighbourhood')
print(data['neighbourhood'].isnull().sum())
# Out:
# 0

# %%
#Valores nulos en 'review_scores_rating'
nulos_review_scores_rating = data[data['review_scores_rating'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
if len(nulos_review_scores_rating) > 0:
    for col in nulos_review_scores_rating.columns:
        print(col)
        if len(nulos_review_scores_rating[col].unique()) > 5:
            print(nulos_review_scores_rating[col].unique()[:5], '...')
        else:
            print(nulos_review_scores_rating[col].unique())
else:
    print("No hay valores nulos en review_scores_rating")
# Out:
# id
# [13418779 14066228  6226658  2479317  5520582] ...
# log_price
# [6.62007321 4.24849524 4.09434456 6.95654544 3.8286414 ] ...
# property_type
# ['House' 'Apartment' 'Condominium' 'Loft' 'Townhouse'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials}'
#  '{TV,Internet,"Wireless Internet",Kitchen,"Free parking on premises","Pets allowed","Pets live on this property",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector",Essentials,Shampoo,"Lock on bedroom door","24-hour check-in",Hangers}'
#  '{Internet,"Wireless Internet","Air conditioning",Kitchen,"Indoor fireplace","Buzzer/wireless intercom",Heating,Washer,Dryer,Essentials,Hangers,"Laptop friendly workspace"}'
#  '{TV,"Wireless Internet","Air conditioning",Kitchen,Heating,Washer,Dryer,"Smoke detector","Fire extinguisher",Essentials,"Lock on bedroom door","Hair dryer",Iron,"translation missing: en.hosting_amenity_49"}'
#  '{"Wireless Internet","Air conditioning",Kitchen,"Free parking on premises",Gym,"Elevator in building","Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Hangers,Iron,"translation missing: en.hosting_amenity_50"}'] ...
# accommodates
# [4 2 5 1 9] ...
# bathrooms
# [1.  1.5 2.  2.5 3. ] ...
# bed_type
# ['Real Bed' 'Pull-out Sofa' 'Futon' 'Airbed' 'Couch']
# cancellation_policy
# ['flexible' 'moderate' 'strict' 'super_strict_30' 'super_strict_60']
# cleaning_fee
# [ True False]
# city
# ['SF' 'LA' 'Chicago' 'DC' 'NYC'] ...
# description
# ['This light-filled home-away-from-home is super clean and comes with all of the modern amenities travelers could want. Located on a quiet street in the very trendy, super central Lower Haight neighborhood. 15 minutes to Superbowl City! Avail 2/4-2/8. Tucked away on a quaint and quiet one-way street just one block away from the restaurants, shops and bars on Haight Street. There are trains and buses just a block away to get around the city. Super central and trendy!'
#  'Newly furnished room in beach apartment one street up from the water! Relaxing ocean view from the patio in this quaint pet-friendly complex. Right next to the Riviera Village, full of restaurants and shopping! If you would like to rent on days not listed under availability, please message! I may be able to accommodate :)'
#  "Just west of vibrant Wicker Park and Ukranian Village, welcome home to Humboldt Park.  There's a really great urban park just 2 minutes away, where you can get a breath of air and also really great views of the city. This home is shared by 2 working ceramic artists.  Outside of day jobs as freelancers we both keep studio space across town, so the home for us is a clean and comfortable space, with lots of light and creative touches in every corner.  This apartment has the special character of being a duplex with the added bonus of a nice fireplace, which we especially enjoy during the cold Chicago winter!  Currently we are renting one room to a doctor, and I am taking time away from Chicago and offering my room to AirBnb guests. Guests are welcome to be at home in their room, or in either of the common sitting areas.  Kitchen use is permitted, with courtesy of hosts.  Ask for details & kitchen orientation when you check-in. With 2 roommates sharing the duplex on a permanent basis, eithe"
#  'Our place is a modern, spacious apartment on the upper level of a walk-up in the historic Dupont Circle neighborhood. Located on a quiet, but hip street with local bars and restaurants. Exactly 1 mile to the White House! Plus just a few blocks to the Dupont metro station and 14th street/U Street restaurants and bars. Also walking distance to Georgetown, Logan Circle, and Adams Morgan areas. One bedroom, one bathroom. One queen bed in the bedroom, along with a flat screen TV and plenty of space for your luggage.  An additional queen air mattress is available for use in the living room  (Insta-Bed Raised Air Mattress with Never Flat Pump - Queen). We have a memory foam mattress pad, extra sheets, and pillows available for use if this bed is needed. Plenty of room in either the bedroom or living room for the air mattress. I will make my self available to give you a set of keys upon your arrival. You can leave the keys in the apartment when you check out.'
#  'Our place is fully renovated with a nice and clean carpet in the bedroom and living room. You will have your own private bedroom and bathroom. There is one parking spot in the basement. The neighborhood is quiet and nice. Groceries stores, restaurants and The Grove mall nearby. Quite in the middle of LA: - 20 min by car to Santa Monica and Venice beach - 10 min by car to Hollywood boulevard - 20 min by car to Downtown LA Buses and subways stations closed  You will love this place. We will be here to help and guide you.'] ...
# first_review
# <DatetimeArray>
# ['1677-10-21 00:00:00', '2017-03-18 00:00:00', '2016-11-14 00:00:00',
#  '2017-08-30 00:00:00', '2016-03-15 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [ 1 -1  0]
# host_identity_verified
# [ 1  0 -1]
# host_response_rate
# [ -1 100  83  50   0] ...
# host_since
# <DatetimeArray>
# ['2015-04-19 00:00:00', '2016-05-10 00:00:00', '2012-09-10 00:00:00',
#  '2015-05-19 00:00:00', '2017-03-18 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['f' 't']
# last_review
# <DatetimeArray>
# ['1677-10-21 00:00:00', '2017-04-05 00:00:00', '2016-11-14 00:00:00',
#  '2017-08-30 00:00:00', '2016-02-01 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# latitude
# [37.77200448 33.81322842 41.90824021 38.91127529 34.06407656] ...
# longitude
# [-122.43161868 -118.38943365  -87.69524167  -77.03727241 -118.34591019] ...
# name
# ['Beautiful Flat in the Heart of SF!' 'Beach Pad 1 min walk to the ocean!'
#  'Sweet Home Chicago' 'Dupont 1 bedroom - 1 mile from the White House!'
#  'Cosy private room/bathroom in Miracle Mile.'] ...
# neighbourhood
# ['Lower Haight' 'Torrance' 'Humboldt Park' 'Dupont Circle' 'Mid-Wilshire'] ...
# number_of_reviews
# [ 0  1  4 28  6] ...
# review_scores_rating
# [nan]
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/72208dad-9c86-41ea-a735-43d933111063.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/be827784-a092-4b3c-8f69-f957414eb48c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/996e04cd-56c5-4705-a420-a2962ac9d85c.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/a24c135a-0379-4ed8-a37a-2eadd7acc164.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/14bf8357-c56f-4cb8-8f98-9a76ad040dbb.jpg?aki_policy=small'] ...
# zipcode
# ['94117.0' '90277' '60622' '20009' '90036'] ...
# bedrooms
# [2. 1. 4. 0. 3.] ...
# beds
# [2. 1. 4. 3. 5.] ...

# %%
#Como no hay relaciones se cambian los valores nulos a -1
data['review_scores_rating'] = data['review_scores_rating'].fillna(-1)
print(data['review_scores_rating'].isnull().sum())
# Out:
# 0

# %%
#Valores nulos en 'thumbnail_url'
nulos_thumbnail_url = data[data['thumbnail_url'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
if len(nulos_thumbnail_url) > 0:
    for col in nulos_thumbnail_url.columns:
        print(col)
        if len(nulos_thumbnail_url[col].unique()) > 5:
            print(nulos_thumbnail_url[col].unique()[:5], '...')
        else:
            print(nulos_thumbnail_url[col].unique())
else:
    print("No hay valores nulos en thumbnail_url")
# Out:
# id
# [ 3808709 17423675  2658946 17589436   851978] ...
# log_price
# [4.74493213 5.01063529 5.29831737 4.88280192 5.19295685] ...
# property_type
# ['Apartment' 'House' 'Loft' 'Condominium' 'Other'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{TV,Internet,"Wireless Internet","Air conditioning",Kitchen,"Elevator in building",Heating,"Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Shampoo}'
#  '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Free parking on premises",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Safety card","Fire extinguisher",Essentials,Shampoo,"24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace"}'
#  '{TV,"Cable TV",Internet,"Wireless Internet","Air conditioning",Kitchen,"Free parking on premises",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Safety card","Fire extinguisher",Essentials,Shampoo,"24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self Check-In",Lockbox}'
#  '{TV,"Cable TV",Internet,"Wireless Internet","Air conditioning","Wheelchair accessible",Kitchen,Elevator,"Buzzer/wireless intercom",Heating,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace"}'
#  '{TV,Internet,"Wireless Internet","Air conditioning",Pool,Kitchen,"Free parking on premises","Smoking allowed","Pets allowed",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector",Shampoo}'] ...
# accommodates
# [2 4 6 3 5] ...
# bathrooms
# [ 1.   1.5  2.   2.5 -1. ] ...
# bed_type
# ['Real Bed' 'Pull-out Sofa' 'Airbed' 'Futon' 'Couch']
# cancellation_policy
# ['moderate' 'strict' 'flexible' 'super_strict_60' 'super_strict_30']
# cleaning_fee
# [ True False]
# city
# ['DC' 'LA' 'NYC' 'Chicago' 'SF'] ...
# description
# ["Cool, cozy, and comfortable studio located in the heart of the city. Literally a 10 min walk to Columbia Heights metro where you'll find shopping, theater, bars and diverse restaurants. Fits two very well, and is very convenient to other great areas. Welcome home!  It's in a diverse building,  where you meet alot of international people. It's located around different embassies, whom may provide a tour.  Theres tons of people from over the world! Tons of different restaurants,  and cultural things to do. Less than a mile walk to Dupont Circle, U Street, Adams Morgan, Columbia Heights metro.  Tons of buses, and underground metro at your fingertips I can provide groceries for an affordable fee"
#  "A 1044 sq. ft., 1950's beach house. 3 Blocks from the beach, on the green belt, 1 block from the Valley Park. Situated between the Manhattan and Hermosa Piers close to all the Southbay has to offer. This is a 1044sq. ft., 1950's beach house with an open floor plan. One bedroom has an antique Queen Bed, the 2nd bedroom/office has a full size murphy bed, and a sofa w/foldout bed in the living room. Beach gear is available; chairs, towels, umbrellas. One car garage no garage door opener. Ample, free street parking available, no permit required. I can usually park right in front of the house. The laundry room is accessed through the garage side door. Luggage racks, closet space and dressers in each bedroom for guest use. I try not to disturb my guests unnecessarily during their stay, but am available if needed. I've lived in the Southbay since 1969. I hope you enjoy stay as much as I have loved living here for so many years. It is a residential, family friendly neighborhood. Hermosa means "
#  'Amazing location at the heart of U street and 14th street neighbourhoods! Great 2 bedroom apartment (sleeps 6) in the heart of DC with excellent walkability and a great choice of restaurants, coffee shops, bars, grocery stores within a couple minutes walk. White house is within a 30 min walk or 5 min taxi ride away. Metro station only 7 minutes away! Home is open plan layout with hard wood floors, exposed brick walls, stainless steel kitchen appliances, a private deck and a parking space. Come stay in our lovely, modern home, right around the corner from 14th street`s action!  14th st is famous in DC for its trendy storefronts, endless dining options, and the bustling music scene. Families and friends will have no trouble finding entertainment and culture right outside of your door!  We host the basement unit as well, so for those with larger groups, please inquire about opening up the rest of the home to sleep an additional 4 guests.  Jack and Jill set up allows both the master bedroo'
#  'I am renting a very spacious, unique, bright L shape studio filled with character for perfect NYC vibe & getaway. Apt is located Lower East Side (LES) walking distant SOHO,Nolita, Chinatown, lots of restaurants and bars and close to the F,B,D,J,M,Z . Hello all , I am happy to rent my apartment to  respectful, clean individuals. I love my apartment and want to make sure it is in good hands while away.  My apt. is located one of the most convenient and attractive neighborhood  in Manhattan, Lower East Side (LES). It\'s a very quiet  apartment best fits 2 guests. ( one Queen size real bed 60" x 80" and one single day bed) 15 feet wide window provides great light and eastern views of downtown Manhattan, lying in bed and gazing out the window is lovely. Furniture\'s are carefully selected by award winner interior designer  and items within the space give the whole apartment a colorful , light and airy / spacious feeling. Any questions I am happy to answer and after 14+ years living in New Yor'
#  "This home is filled with love & laughter! Modern, Clean French doors, double door bedroom, flat screen, ps4, movies, Netflix and A/C! Pool/Parking! Fully furnished right in the center of hollywood! 5 minutes walking to Chinese theatre and near most exciting spots all the tourists go! Parking included! You'llBeLivingALosAngelesLifeTheRightWay! :)"] ...
# first_review
# <DatetimeArray>
# ['2015-05-12 00:00:00', '2015-07-02 00:00:00', '2017-02-18 00:00:00',
#  '2015-09-26 00:00:00', '2015-12-30 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [ 1  0 -1]
# host_identity_verified
# [ 1  0 -1]
# host_response_rate
# [100  71  -1  86   0] ...
# host_since
# <DatetimeArray>
# ['2015-03-01 00:00:00', '2015-06-11 00:00:00', '2012-10-12 00:00:00',
#  '2015-08-17 00:00:00', '2015-09-26 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['t' 'f']
# last_review
# <DatetimeArray>
# ['2017-01-22 00:00:00', '2016-11-18 00:00:00', '2017-04-30 00:00:00',
#  '2016-12-12 00:00:00', '2016-08-03 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# latitude
# [38.92562692 33.87586236 38.91963001 40.7190863  34.05158405] ...
# longitude
# [ -77.03459552 -118.40329265  -77.03118943  -73.99028485 -118.24292309] ...
# name
# ['Great studio in midtown DC' 'Sand Section Beach Bungalow'
#  'Charming 2 bdrm in trendy U/14th streets w/parking'
#  'Amazing LES apt - cool, bright...' 'Sweet Hollywood Home / 1bd1bth'] ...
# neighbourhood
# ['Columbia Heights' 'Hermosa Beach' 'U Street Corridor' 'Lower East Side'
#  'Unknown Neighbourhood'] ...
# number_of_reviews
# [ 4 29 13 26  1] ...
# review_scores_rating
# [40. 97. 89. 86. 95.] ...
# thumbnail_url
# [nan]
# zipcode
# ['20009' '90254' '10002' '90028' '90046'] ...
# bedrooms
# [0. 2. 1. 3. 4.] ...
# beds
# [ 1.  2.  3.  4. nan] ...

# %%
#cambiar los valores nulos a 'Unknown Thumbnail_URL'
data['thumbnail_url'] = data['thumbnail_url'].fillna('Unknown Thumbnail_URL')
print(data['thumbnail_url'].isnull().sum())
# Out:
# 0

# %%
#Valores nulos en 'zipcode'
nulos_zipcode = data[data['zipcode'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
if len(nulos_zipcode) > 0:
    for col in nulos_zipcode.columns:
        print(col)
        if len(nulos_zipcode[col].unique()) > 5:
            print(nulos_zipcode[col].unique()[:5], '...')
        else:
            print(nulos_zipcode[col].unique())
else:
    print("No hay valores nulos en zipcode")
# Out:
# id
# [19407360  4576821  7144212 19839317 11742647] ...
# log_price
# [4.55387689 4.24849524 4.82831374 7.56941179 3.8918203 ] ...
# property_type
# ['Apartment' 'Villa' 'House' 'Guest suite' 'Condominium'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{TV,"Wireless Internet",Pool,Kitchen,"Elevator in building","Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,"Lock on bedroom door","Laptop friendly workspace","translation missing: en.hosting_amenity_50"}'
#  '{"Wireless Internet",Kitchen,Breakfast,Elevator,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'
#  '{TV,"Cable TV",Internet,"Wireless Internet","Air conditioning",Kitchen,Doorman,Gym,Breakfast,Elevator,"Buzzer/wireless intercom",Heating,Washer,Dryer,"Smoke detector",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50","Self Check-In",Doorman,Bathtub,"Babysitter recommendations"}'
#  '{TV,"Cable TV",Internet,"Wireless Internet","Air conditioning",Pool,Kitchen,"Free parking on premises","Hot tub","Indoor fireplace","Buzzer/wireless intercom","Family/kid friendly","Suitable for events",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Safety card","Fire extinguisher",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace"}'
#  '{TV,"Cable TV",Internet,"Wireless Internet","Air conditioning",Kitchen,"Smoking allowed",Breakfast,"Pets live on this property",Dog(s),Cat(s),"Buzzer/wireless intercom",Heating,"Family/kid friendly","Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace"}'] ...
# accommodates
# [2 1 8 3 6] ...
# bathrooms
# [1.  3.5 2.  1.5 3. ] ...
# bed_type
# ['Real Bed' 'Futon' 'Pull-out Sofa' 'Airbed' 'Couch']
# cancellation_policy
# ['flexible' 'strict' 'super_strict_60' 'moderate']
# cleaning_fee
# [ True False]
# city
# ['LA' 'NYC' 'Chicago' 'SF' 'Boston'] ...
# description
# ['Retro, Melrose Place-esque studio apartment steps away from Sunset Blvd + close to all the action in West Hollywood and Hollywood.  2-minute walk to 8000 Sunset Plaza (Starbucks, Crunch Gym, Trader Joes, restaurants, smoothies..).  Building is secure with amazing neighbors, vibe, and energy. Mediterranean-style building with extremely well taken care of pool. Super comfortable, large studio apartment. Bedroom, stocked bathroom, refrigerator, coffee maker, WiFi, office area, Apple TV .'
#  "Single person studio available in the heart of Park Slope! Just one block from Prospect Park. Close to wonderful restaurants and bars. The apartment is about a five minute walk to the F G trains; about a 10 minute walk to the B Q 2 3. The building is very quiet and mostly occupied by young professionals. I am looking for a guest who will respect the place, keep it tidy and can be a quiet neighbor. Perfect getaway for someone who's looking for a quaint spot in a beautiful park of Brooklyn."
#  'Real Luxury with a home feel!  Complimentary continental breakfast at Rooftop weekdays. 24 hour gym access.  Hardwood floors, chandelier, renovated finishes.  Huge windows in room!  Restaurants, markets, banks... everything you need a step away.  24 hour pharmacy right next door! 5 minutes walk from Seaport, 10 minutes from battery park. Beautiful area for jogging or just a nice stroll.  Nice homey apartment, organized and clean always :) Full access to amenities. Minimum interaction, available to help when needed via phone or text. Several train lines less than 5 minutes walking. No shoes in house :)  Wifi and tv available in lounge.'
#  'A sleek décor defined by clean lines and punctuated by unique, quirky conversation pieces. This is a gorgeous, modern, and clean Hollywood Villa. This is a gorgeous, modern, and clean Hollywood Villa. It is equipped with A/C, heater, washer/dryer, beautiful fresh linens, extremely comfortable mattresses, indoor/outdoor fire places, indoor/outdoor wireless sound system, a pool, hot tub, alfresco shower, wireless internet, printer, cable TV (HBO), security alarm system, and security cameras. Maid services are available upon request and at extra cost, however a gardener and pool service is included weekly at no cost (every Wednesday). Each master bedroom features a King size bed, and the guest bedroom features a Queen size bed. There are also 2 Queen size, extra plush and luxurious blow up mattresses available, perfect for friends who are temporarily visiting. BEDROOM & BATHROOM Bedroom 1 - Master: King size beds, Ensuite bathroom with stand-alone shower & bathtub, Toiletries, Fireplace, '
#  'We live in the Bushwick neighborhood of Brooklyn near the Myrtle-Wyckoff subway stop. The room has a full-size bed, a small dresser and desk and is great for students. We can also configure the room with two beds if you prefer. It is in the downstairs of our home, so it has one small window, facing our private garden, and it is more quiet and private than the room in the front of the house. Our home is warm and inviting and we have a dog, a cat and a young son. Guests can get help and suggestions throughout most of the day, as one or both of us usually works from home. Our neighborhood is vibrant and eclectic with a lot of art galleries and cool restaurants We are 2 blocks from the L and M trains at Myrtle-Wyckoff'] ...
# first_review
# <DatetimeArray>
# ['2016-07-17 00:00:00', '2016-07-04 00:00:00', '2017-05-08 00:00:00',
#  '2016-06-28 00:00:00', '2015-10-18 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [ 1 -1  0]
# host_identity_verified
# [ 1  0 -1]
# host_response_rate
# [ -1 100  94  92  63] ...
# host_since
# <DatetimeArray>
# ['2013-06-20 00:00:00', '2014-11-25 00:00:00', '2015-09-22 00:00:00',
#  '2015-05-01 00:00:00', '2014-06-16 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['f' 't']
# last_review
# <DatetimeArray>
# ['2016-07-17 00:00:00', '2017-09-29 00:00:00', '2017-07-16 00:00:00',
#  '2016-06-28 00:00:00', '2017-08-29 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# latitude
# [34.10068649 40.66902581 40.70468493 34.06834747 40.69894879] ...
# longitude
# [-118.36420358  -73.97707905  -74.00722467 -118.37398109  -73.91356958] ...
# name
# ['Retro West Hollywood Studio + Pool!' 'Charming Studio in Park Slope'
#  'Private room in Amazing Lux building!' 'Modern Luxury: 116852'
#  'Good Living in Brooklyn! Dbl Rm'] ...
# neighbourhood
# ['Unknown Neighbourhood' 'Park Slope' 'Financial District' 'Bushwick'
#  'Gramercy Park'] ...
# number_of_reviews
# [ 1  2  3 66  9] ...
# review_scores_rating
# [100.  96.  95.  93.  85.] ...
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/c67ecdec-acdd-49d6-80e5-bed6fcc70805.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/6666b75f-4bc7-447c-adda-f6ec01a4166f.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/e05d4db6-24d3-46f6-964a-a770961371b9.jpg?aki_policy=small'
#  'Unknown Thumbnail_URL'
#  'https://a0.muscache.com/im/pictures/b143c05f-d464-49ab-9247-342283000313.jpg?aki_policy=small'] ...
# zipcode
# [nan]
# bedrooms
# [1. 0. 3. 2. 5.] ...
# beds
# [ 1.  3.  2. 13.  5.] ...

# %%
#Cambiar los valores nulos a 'NOZIPCODE'
data['zipcode'] = data['zipcode'].fillna('NOZIPCODE')
print(data['zipcode'].isnull().sum())
# Out:
# 0

# %%
#Valores nulos en 'bedrooms'
nulos_bedrooms = data[data['bedrooms'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
if len(nulos_bedrooms) > 0:
    for col in nulos_bedrooms.columns:
        print(col)
        if len(nulos_bedrooms[col].unique()) > 5:
            print(nulos_bedrooms[col].unique()[:5], '...')
        else:
            print(nulos_bedrooms[col].unique())
else:
    print("No hay valores nulos en bedrooms")
# Out:
# id
# [ 7575345 17109866 19360685 12130093  8934887] ...
# log_price
# [5.433722   4.24849524 5.26269019 4.38202663 4.53259949] ...
# property_type
# ['Apartment' 'Loft' 'Other' 'House' 'Villa'] ...
# room_type
# ['Entire home/apt' 'Private room']
# amenities
# ['{TV,"Cable TV",Internet,"Wireless Internet","Air conditioning",Kitchen,"Indoor fireplace",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Hangers,Iron,"Laptop friendly workspace","Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,"Dishes and silverware","Cooking basics",Stove,"Long term stays allowed"}'
#  '{Internet,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'
#  '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Heating,Dryer}'
#  '{TV,Internet,"Wireless Internet","Air conditioning",Kitchen,Heating,"Family/kid friendly","Smoke detector","Carbon monoxide detector","Fire extinguisher","Self Check-In",Keypad}'
#  '{Internet,"Wireless Internet","Air conditioning",Kitchen,Elevator,"Buzzer/wireless intercom",Heating}'] ...
# accommodates
# [2 1 4 6 3]
# bathrooms
# [ 1.  -1.   1.5]
# bed_type
# ['Real Bed' 'Futon' 'Pull-out Sofa']
# cancellation_policy
# ['super_strict_30' 'flexible' 'moderate' 'strict']
# cleaning_fee
# [ True False]
# city
# ['Boston' 'LA' 'SF' 'Chicago' 'NYC'] ...
# description
# ['Price Quoted is for rentals under 7 nights.   Discounted weekly and monthly rates. These finely renovated suites offer a clean and modern home just moments away from the Prudential and Copley shopping districts, tourist attractions and the Hynes Convention Center.  Live in the fashionable South End where small bistros and boutiques can be found amongst the backdrop of historical residences and brownstones. Absorb the city lights from our common roof deck and enjoy all the modern conveniences of home.  The Christopher offers a varitety of unique suites. Some have gas fireplaces and marble bathrooms and exposed brick walls.  These Grand Studio Suites include a queen bed and full private marble bathroom.  Recently updated furnishings. Accessorized kitchenette has full size refrigerator, 4 stove top burners, microwave, toaster oven, coffee maker and dining table or work desk with two bar stools.  --Free WiFi, Cable TV and Local Phone Service --42" HDTV --Laundry facilities in byulding Comm'
#  "My comfy little abode in the heart of Venice, is minutes from the beach with plenty of permit free street parking. Along with a separate bathroom and spacious kitchen for easy cooking, it'll make it easy to find your rhythm and make the space yours, feeling at home in no time. It's uniquely mine and I put a lot of love into it adding my own personal touches. It's been transformed a few times and it's grown along side me for many years now. If you're looking for an upmarket, modern apartment, you might be looking in the wrong place. The studio is modest, but very cozy and welcoming with a great energy! For bare basics, it has exactly what you need. My spot is lovely and it'll be all yours if you choose to take it. No roommates, no one to answer to and no one to tip toe around. Mine is a small building with only 8 units. Unfortunately there aren't all the bells and whistles in terms of amenities, but we do have a laundry room in the building which is coin operated (coins not provided). A"
#  'Studio apartment in great location!'
#  'This is a very small  studio apartment with a private entrance.  The apartment is located on the rear half of our first floor. It has its own entrance. It consists of a kitchen and a small bedroom with a queen sized bed (new since October 2016) and bathroom with a tub and shower.  There is a kitchen with a stove and mini fridge and sink and microwave plus a small table for two. We have a Roku Box for tv watching and excellent cable internet. The Roku has Amazon Prime, Netflix and a bunch of other channels. We have hi-speed Comcast internet. You will be in your own intact tiny apartment. You will not see me or my family at all unless you run into us outdoors. My family lives in the building but we are not home 24/7. We are available to answer questions, especially via email.  Guests let themselves in with a key code and generally have total privacy from us unless they need help with anything. Ukrainian Village was just named "Hottest Neighborhood in America" by Trulia. Our address has a'
#  "Enjoy the privacy of staying in a classic studio in the heart of one of Brooklyn's most beautiful neighborhoods. Classic studio in the heart of one of Brooklyn's most beautiful neighborhoods. This apartment is in a pre-war building with beautiful hardwood floors and an expansive view of the Manhattan skyline and rooftops of Brooklyn. The space is essentially a main room plus a small foyer, big walk-in closet and a bathroom. It is fully furnished with laundry in the basement, TV, DVD, stereo, and Wi-Fi. The apartment has internet, a TV antenna, but no cable TV service. You can easily attach you laptop to the stereo/TV for streaming purposes. The space can accommodate an individual or couple. I'm sure you'll feel the love in my cozy corner of Brooklyn bohemia! I will be available to meet you at arrival and departure, but will be staying elsewhere during your visit. Located in the heart of Fort Greene, Brooklyn. So much to love!  One of the oldest parks in NYC, farmer's market and the fam"] ...
# first_review
# <DatetimeArray>
# ['2011-09-22 00:00:00', '1677-10-21 00:00:00', '2009-07-03 00:00:00',
#  '2015-05-14 00:00:00', '2013-07-13 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [1]
# host_identity_verified
# [1 0]
# host_response_rate
# [ 88 100  -1  50  80] ...
# host_since
# <DatetimeArray>
# ['2009-07-10 00:00:00', '2016-03-30 00:00:00', '2014-01-08 00:00:00',
#  '2009-05-19 00:00:00', '2012-04-02 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['f' 't']
# last_review
# <DatetimeArray>
# ['2015-10-24 00:00:00', '1677-10-21 00:00:00', '2017-05-02 00:00:00',
#  '2015-05-14 00:00:00', '2017-02-19 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# latitude
# [42.34259444 33.99460542 37.77397054 41.90284494 40.68810768] ...
# longitude
# [ -71.0794207  -118.45007485 -122.44502972  -87.6818296   -73.97236015] ...
# name
# ['[1294] Grand Studio - South End' 'Cozy Studio minutes from the beach'
#  'Studio in amazing neighborhood ' 'Tiny Studio Apartment 94 Walk Score'
#  'Feel the Brooklyn Love!'] ...
# neighbourhood
# ['South End' 'Venice' 'Western Addition/NOPA' 'Ukrainian Village'
#  'Fort Greene'] ...
# number_of_reviews
# [  9   0 242   1  40] ...
# review_scores_rating
# [ 89.  -1.  91. 100.  94.] ...
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/5054399/e8d14971_original.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/475d80ca-afd6-4910-b58e-2f74b9406a48.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/29504477/64435d4a_original.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/51073/16c81c7e_original.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/9676885/42d386d0_original.jpg?aki_policy=small'] ...
# zipcode
# ['02118' '90291' '94117' '60622' '11205'] ...
# bedrooms
# [nan]
# beds
# [ 1. nan  2.  3.  4.]

# %%
#Cambiar los valores nulos a -1
data['bedrooms'] = data['bedrooms'].fillna(-1)
print(data['bedrooms'].isnull().sum())
# Out:
# 0

# %%
#Valores nulos en 'beds'
nulos_beds = data[data['beds'].isnull()]
#Imprimir los valores únicos de cada feature para ver si hay relacion de este valor nulo con otro feature
if len(nulos_beds) > 0:
    for col in nulos_beds.columns:
        print(col)
        if len(nulos_beds[col].unique()) > 5:
            print(nulos_beds[col].unique()[:5], '...')
        else:
            print(nulos_beds[col].unique())
else:
    print("No hay valores nulos en beds")
# Out:
# id
# [17109866 13559613 11084417 19360685  4280150] ...
# log_price
# [4.24849524 4.60517019 5.29831737 5.26269019 5.6347896 ] ...
# property_type
# ['Apartment' 'House' 'Bed & Breakfast' 'Dorm' 'Other'] ...
# room_type
# ['Entire home/apt' 'Private room' 'Shared room']
# amenities
# ['{Internet,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,Hangers,"Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}'
#  '{}' '{TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Heating,Dryer}'
#  '{"Family/kid friendly"}'
#  '{Internet,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"24-hour check-in",Hangers,Iron,"Laptop friendly workspace"}'] ...
# accommodates
# [ 1  2  3  6 16] ...
# bathrooms
# [ 1.  -1.   2.5  1.5  2. ] ...
# bed_type
# ['Real Bed' 'Pull-out Sofa']
# cancellation_policy
# ['flexible' 'moderate' 'strict']
# cleaning_fee
# [False  True]
# city
# ['LA' 'NYC' 'SF' 'DC' 'Boston'] ...
# description
# ["My comfy little abode in the heart of Venice, is minutes from the beach with plenty of permit free street parking. Along with a separate bathroom and spacious kitchen for easy cooking, it'll make it easy to find your rhythm and make the space yours, feeling at home in no time. It's uniquely mine and I put a lot of love into it adding my own personal touches. It's been transformed a few times and it's grown along side me for many years now. If you're looking for an upmarket, modern apartment, you might be looking in the wrong place. The studio is modest, but very cozy and welcoming with a great energy! For bare basics, it has exactly what you need. My spot is lovely and it'll be all yours if you choose to take it. No roommates, no one to answer to and no one to tip toe around. Mine is a small building with only 8 units. Unfortunately there aren't all the bells and whistles in terms of amenities, but we do have a laundry room in the building which is coin operated (coins not provided). A"
#  'I am renting my room for 45$ per night. Jan, 4th-12th and Jan 15th - Feb, 8th. Two blocks from the J(Chauncey) and L(Wilson) train. Roomates: Two girls, 26/23 Bed/Internet/Utilities incl. Apartment clean, room with two windows(sunlight), no smoking in the apartment  Cooper at Evergreen '
#  'One bedroom provided in a two bedroom condo.  Two levels, bedroom upstairs with 1 full bath and 1 half bath. Must love cats and a very old dog. Animal haters are not welcome.'
#  'Studio apartment in great location!'
#  'Nice clean private room with bathroom and private entrance. Nice view of a KOI pond. Lots of fun entertaining things near by. Universal Studios and Hollywood less than 5 miles away. Shopping right across the street. Nice quiet tree lined streets. '] ...
# first_review
# <DatetimeArray>
# ['1677-10-21 00:00:00', '2013-03-13 00:00:00', '2016-07-01 00:00:00',
#  '2016-05-21 00:00:00', '2016-09-25 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# host_has_profile_pic
# [1]
# host_identity_verified
# [1 0]
# host_response_rate
# [100  -1  75  40  50] ...
# host_since
# <DatetimeArray>
# ['2016-03-30 00:00:00', '2012-12-22 00:00:00', '2011-10-03 00:00:00',
#  '2014-01-08 00:00:00', '2013-06-27 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# instant_bookable
# ['f' 't']
# last_review
# <DatetimeArray>
# ['1677-10-21 00:00:00', '2016-11-18 00:00:00', '2016-09-21 00:00:00',
#  '2016-05-21 00:00:00', '2016-09-25 00:00:00']
# Length: 5, dtype: datetime64[ns] ...
# latitude
# [33.99460542 40.68542293 34.14461024 37.77397054 34.16052443] ...
# longitude
# [-118.45007485  -73.9073207  -118.41580116 -122.44502972 -118.43572743] ...
# name
# ['Cozy Studio minutes from the beach' 'Apt in Bushwick'
#  'One Private Room in Studio City, CA' 'Studio in amazing neighborhood '
#  'Nice,Cozy ,Clean private Room'] ...
# neighbourhood
# ['Venice' 'Bushwick' 'Studio City' 'Western Addition/NOPA' 'Sherman Oaks'] ...
# number_of_reviews
# [ 0  5  6  1 16] ...
# review_scores_rating
# [ -1.  96.  83. 100.  95.] ...
# thumbnail_url
# ['https://a0.muscache.com/im/pictures/475d80ca-afd6-4910-b58e-2f74b9406a48.jpg?aki_policy=small'
#  'Unknown Thumbnail_URL'
#  'https://a0.muscache.com/im/pictures/2274779/a269089e_original.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/29504477/64435d4a_original.jpg?aki_policy=small'
#  'https://a0.muscache.com/im/pictures/11886827/8fdffbd3_original.jpg?aki_policy=small'] ...
# zipcode
# ['90291' '11207' '91604' '94117' '91423'] ...
# bedrooms
# [-1.  1.  0.  4.  2.] ...
# beds
# [nan]

# %%
#Cambiar los valores nulos a -1
data['beds'] = data['beds'].fillna(-1)
print(data['beds'].isnull().sum())
# Out:
# 0

# %% [markdown]
# Conversión de tipos de datos

# %%
#Bedrooms y beds a enteros
data['bedrooms'] = data['bedrooms'].astype(int)
data['beds'] = data['beds'].astype(int)

# %%
#Mapear instant_bookable a 1 y 0 y cambiar a bool
data['instant_bookable'] = data['instant_bookable'].map({'t': 1, 'f': 0}).astype(bool)

# %% [markdown]
# Guardar la data limpia en un nuevo csv

# %%
csv_file = '../data/processed/Airbnb_Data_Processed.csv'
data.to_csv(csv_file, index=False)
print(f"Archivo guardado en {csv_file}")
# Out:
# Archivo guardado en ../data/processed/Airbnb_Data_Processed.csv

# %%
#Guardar en otro csv solo la data importante para el modelo
data2=data[['log_price','property_type','room_type','amenities','accommodates','bathrooms','bed_type','cancellation_policy','cleaning_fee','host_has_profile_pic','host_identity_verified','host_response_rate','instant_bookable','latitude','longitude','number_of_reviews','review_scores_rating','bedrooms','beds']]
data2.to_csv('../data/processed/Airbnb_Data_Processed_2.csv', index=False)
